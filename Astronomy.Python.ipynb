# %%
# Topic : Astro Units with Plots.
# Solution & notes by Akhona Njeje.
# Date : 11 Oct 2023.



import matplotlib.pyplot as plt 
data = [1,2,5]
plt.plot(data)
plt.show()

# %%
x = [0,2,5,8,10]
y = [1,5,6,7,12]
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(True)
plt.axis([0,11,1,12])
plt.show()

# %%
from astropy import units as u

q = 42*u.meter
print(q)
# Out:
# 42.0 m

# %%
q.value
# Out:
# 42.0

# %%
q.unit
# Out:
# Unit("m")

# %%
d1 = 45*u.m
d2 = 5*u.m
time = 2*u.s

# %%
speed = (d1 - d2)/ time
print(speed)
# Out:
# 20.0 m / s

# %%
# Convert to km.

print(speed.to(u.km/u.hour))
# Out:
# 72.0 km / h

# %%
from astropy import constants as const
print(const.G)   # Gravity.
# Out:
#   Name   = Gravitational constant
#   Value  = 6.6743e-11
#   Uncertainty  = 1.5e-15
#   Unit  = m3 / (kg s2)
#   Reference = CODATA 2018

# %%
print(const.h)
# Out:
#   Name   = Planck constant
#   Value  = 6.62607015e-34
#   Uncertainty  = 0.0
#   Unit  = J s
#   Reference = CODATA 2018

# %%
# Speed of light.

print(const.c)
# Out:
#   Name   = Speed of light in vacuum
#   Value  = 299792458.0
#   Uncertainty  = 0.0
#   Unit  = m / s
#   Reference = CODATA 2018

# %%
print(const.c.to(u.km/u.s))
# Out:
# 299792.458 km / s

# %%
print(const.c.to("pc/yr"))
# Out:
# 0.30660139378555057 pc / yr

# %%
from astropy.constants import c,m_e   # m_e =  mass of electron.
c
# Out:
# <<class 'astropy.constants.codata2018.CODATA2018'> name='Speed of light in vacuum' value=299792458.0 uncertainty=0.0 unit='m / s' reference='CODATA 2018'>

# %%
m_e
# Out:
# <<class 'astropy.constants.codata2018.CODATA2018'> name='Electron mass' value=9.1093837015e-31 uncertainty=2.8e-40 unit='kg' reference='CODATA 2018'>

# %%
m = m_e
E = m*c**2
print(E)
# Out:
# 8.187105776823886e-14 kg m2 / s2

# %%
# Conver E to a mega eletron vault.

E.to("MeV")
# Out:
# <Quantity 0.51099895 MeV>
